# %%
import sys
import os
import os.path
import fnmatch
from lxml import etree
from lxml.etree import tostring
import re
from collections import defaultdict
from collections import OrderedDict
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
from pylab import plot
import pickle
import re
import matplotlib.patches as mpatches
from nltk.tokenize import word_tokenize
# Out:
# /usr/local/lib/python3.5/dist-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
def process_files(list_of_files, path_in):
    
    words_dict=defaultdict(list)
    length_dict=defaultdict(list)
    chaps_dict=defaultdict(list)
    divs_dict=defaultdict(list)
    first_dict=defaultdict(list)
    last_dict=defaultdict(list)
    first_ent_dict=defaultdict(list)
    last_ent_dict=defaultdict(list)
    plot_words=OrderedDict()
    plot_chaps=OrderedDict()
    plot_div1=OrderedDict()
    plot_div2=OrderedDict()
    plot_div3=OrderedDict()
    plot_length=OrderedDict()
    plot_first=OrderedDict()
    plot_last=OrderedDict()
    plot_ent_first=OrderedDict()
    plot_ent_last=OrderedDict()
    filtered=list()
    bugs=list()
    stats=defaultdict(list)
    
    print("Processing "+str(len(list_of_files))+" files. Please wait, this might take some time.")

    for tmpFile in list_of_files:

        tmpFile=tmpFile.replace("/",":")
        fullPath=path_in+tmpFile

        print("\nProcessing file "+tmpFile)

        if os.path.isfile(fullPath):
            tree=etree.parse(fullPath)

        #yearKey=int(tmpFile[:3]+"0")
            yearKey=int(tmpFile[:4])

            words_dict=num_words(words_dict,tree, yearKey, bugs, tmpFile)
            #print(words_dict.keys())
            chaps_dict=num_chapters(chaps_dict,tree,yearKey, bugs,tmpFile)
            
            divs_dict=num_divs(divs_dict, tree, yearKey, bugs, tmpFile)
            
            length_dict=length(length_dict, tree.getroot(), yearKey)
            
            first_dict=num_first(first_dict, tree, yearKey, tmpFile)
            
            last_dict=num_last(last_dict, tree, yearKey, tmpFile)
            
            first_ent_dict=num_ent_first(first_ent_dict, tree, yearKey, tmpFile)
            
            last_ent_dict=num_ent_last(last_ent_dict, tree, yearKey, tmpFile)
            

    plot_words=words_for_plot(words_dict, plot_words)
    plot_chaps=words_for_plot(chaps_dict, plot_chaps)
    plot_length=words_for_plot(length_dict, plot_length)
    plot_div1=divs_for_plot(divs_dict, plot_div1,1)
    plot_div2=divs_for_plot(divs_dict, plot_div2,2)
    plot_div3=divs_for_plot(divs_dict, plot_div3,3)
    plot_first=words_for_plot(first_dict, plot_first)
    plot_last=words_for_plot(last_dict, plot_last)
    plot_ent_first=words_for_plot(first_ent_dict, plot_ent_first)
    plot_ent_last=words_for_plot(last_ent_dict, plot_ent_last)
    #print(bugs)
    fit_words = lin_reg(plot_words)
    fit_chaps = lin_reg(plot_chaps)
    
    print(first_dict)
    print(last_dict)
    
    stats["chapter"].append(fit_chaps)
    stats["chapter"].append(plot_chaps)
    stats["word"].append(fit_words)
    stats["word"].append(plot_words)
    stats["divs"].append(plot_div1)
    stats["divs"].append(plot_div2)
    stats["divs"].append(plot_div3)
    stats["length"].append(plot_length)
    stats["exts"].append(plot_first)
    stats["exts"].append(plot_last)
    stats["ents"].append(plot_ent_first)
    stats["ents"].append(plot_ent_last)
    
    return stats

    #del filtered
    del words_dict
    del chaps_dict
    del plot_words
    del plot_chaps

# %%
def lin_reg(series):

    x = np.array(list(series.keys()))
    y = np.array(list(series.values()))

    x = sm.add_constant(x)

    return sm.OLS(y, x).fit()

# %%
def movingaverage (values, window):
    weights = np.repeat(1.0, window)/window
    sma = np.convolve(values, weights, 'valid')
    return sma

# %%
def plot_stats (fit, plot,limitsX,limitsY, sliding, mycolor, title):
    x1 = list(plot.keys())[0]
    x2 = list(plot.keys())[-1]
    y1 = fit.predict()[0]
    y2 = fit.predict()[-1]
    x = np.array(list(plot.keys()))
    y = np.array(list(plot.values()))
    #print(len(plot.values()))
    yMA = movingaverage(y,sliding)
    plt.figure(figsize=(10, 6))
    plt.plot(list(plot.keys()), list(plot.values()))
    plt.plot(x[len(x)-len(yMA):],yMA,linewidth=5,color=mycolor)
    plt.title(title)
    plt.plot([x1, x2], [y1, y2], color='gray', linewidth=0.5)
    #plt.xlim(min(plot.keys()),max(plot.keys()))
    plt.xlim(limitsX[0],limitsX[1])
    plt.ylim(limitsY[0],limitsY[1])
    #print(plot.keys())
    plt.show()

# %%
def simple_plot (plot, limitsX, limitsY, sliding, mycolor, title):
    plt.figure(figsize=(10, 6))
    x = np.array(list(plot.keys()))
    y = np.array(list(plot.values()))
    yMA = movingaverage(y,sliding)
    plt.plot(x[len(x)-len(yMA):],yMA,linewidth=5,color=mycolor)
    plt.plot(x,y)
    plt.title(title)
    plt.xlim(limitsX[0],limitsX[1])
    plt.ylim(limitsY[0],limitsY[1])
    plt.show()

# %%
def multiple_plots (stats):
    plt.figure(figsize=(10, 6))
    for name in stats.keys():
        x=np.array(list(stats[name]['word'][1].keys()))
        y=np.array(list(stats[name]['word'][1].values()))
        yMA = movingaverage(y,5)
        plt.plot(x[len(x)-len(yMA):],yMA,label=name[1:])
        plt.ylim(min(stats[name]['word'][1].keys()),30000)
        plt.xlim(1800,1910)
    plt.legend(loc='upper left')
    plt.title("nombre moyen de mots par chapitre")
    plt.show()
    plt.figure(figsize=(10, 6))
    for name in stats.keys():
        x=np.array(list(stats[name]['chapter'][1].keys()))
        y=np.array(list(stats[name]['chapter'][1].values()))
        yMA = movingaverage(y,5)
        plt.plot(x[len(x)-len(yMA):],yMA,label=name[1:])
        plt.ylim(0,80)
        plt.xlim(1800,1910)
    plt.legend(loc='upper left')
    plt.title("nombre moyen de chapitres")
    plt.show()

# %%
def hierarchy_plots (plot,limitsX,limitsY, sliding, mycolor, title):
    plt.figure(figsize=(10, 6))
    x = np.array(list(plot[0].keys()))
    y = np.array(list(plot[0].values()))
    yMA = movingaverage(y,sliding)
    plt.plot(x[len(x)-len(yMA):],yMA,linewidth=2,color=mycolor[0])
    x1 = np.array(list(plot[1].keys()))
    y1 = np.array(list(plot[1].values()))
    yMA1 = movingaverage(y1,sliding)
    plt.plot(x1[len(x1)-len(yMA1):],yMA1,linewidth=2,color=mycolor[1])
    x2 = np.array(list(plot[2].keys()))
    y2 = np.array(list(plot[2].values()))
    yMA2 = movingaverage(y2,sliding)
    plt.plot(x2[len(x2)-len(yMA2):],yMA2,linewidth=2,color=mycolor[2])
    plt.legend(loc='upper left')
    plt.xlim(limitsX[0],limitsX[1])
    plt.ylim(limitsY[0],limitsY[1])
    plt.title(title)
    patch1 = mpatches.Patch(color=color[0], label='niveau 1')
    patch2 = mpatches.Patch(color=color[1], label='niveau 2')
    patch3 = mpatches.Patch(color=color[2], label='niveau 3')
    plt.legend(handles=[patch1, patch2, patch3])
    plt.show()

# %%
def first_n_last_plots (plot,limitsX,limitsY, sliding, mycolor, title):
    plt.figure(figsize=(10, 6))
    x = np.array(list(plot[0].keys()))
    y = np.array(list(plot[0].values()))
    yMA = movingaverage(y,sliding)
    plt.plot(x[len(x)-len(yMA):],yMA,linewidth=2,color=mycolor[0])
    x1 = np.array(list(plot[1].keys()))
    y1 = np.array(list(plot[1].values()))
    yMA1 = movingaverage(y1,sliding)
    plt.plot(x1[len(x1)-len(yMA1):],yMA1,linewidth=2,color=mycolor[1])
    plt.xlim(limitsX[0],limitsX[1])
    plt.ylim(limitsY[0],limitsY[1])
    plt.legend(loc='upper left')
    plt.title(title)
    patch1 = mpatches.Patch(color=color[0], label='first')
    patch2 = mpatches.Patch(color=color[1], label='last')
    
    plt.legend(handles=[patch1, patch2])
    plt.show()

# %%
def num_words (words_dict,tree,yearKey,bugs,tmpFile):
    execute=False
    words=list()
    if tree.findall(".//div[@type='chapter']"):
        for chapter in tree.findall(".//div[@type='chapter']"):
            numWords=len(chapter.findall(".//word"))
            words.append(numWords)
            execute=True
    elif tree.findall(".//div[@type='part']"):
        for chapter in tree.findall(".//div[@type='part']"):
            numWords=len(chapter.findall(".//word"))
            words.append(numWords)
            execute=True
    
    else :
        for p in tree.findall(".//p"):
            numWords=len(p.findall(".//word"))
            words.append(numWords)
            execute=True
    
    if execute==True:
        average=sum(words)/len(words)
        words_dict[yearKey].append(average)
    return words_dict

# %%
def length (length_dict, node, yearKey):
    length_dict[yearKey].append(len(node.findall(".//word")))
    return length_dict

# %%
def num_chapters (chaps_dict,tree, yearKey,bugs,tmpFile):
    execute=False
    chapters=list()
    if tree.findall(".//div[@type='chapter']"):
        num_chaps=len(tree.findall(".//div[@type='chapter']"))
        execute=True
    elif tree.findall(".//div[@type='part']"):
        num_chaps=len(tree.findall(".//div[@type='part']"))
        execute=True
    
    else :
        bugs.append(tmpFile+" ; ")
        execute=False
    
    if execute==True:
        chaps_dict[yearKey].append(num_chaps)
        
    else :
        chaps_dict[yearKey].append(0)
    return chaps_dict

# %%
def num_divs (divs_dict,tree, yearKey,bugs,tmpFile):
    execute=False
    chapters=list()
    if tree.findall(".//div[@type='chapter']") and tree.findall(".//div[@type='part']") and tree.findall(".//div[@type='book']"):
        num_divs=3
    elif tree.findall(".//div[@type='chapter']") and tree.findall(".//div[@type='part']"):
        num_divs=2
    elif tree.findall(".//div[@type='chapter']") or tree.findall(".//div[@type='part']"):
        num_divs=1
    else :
        num_divs=0
    
    divs_dict[yearKey].append(num_divs)
    
    return divs_dict

# %%
def num_first (ext_dict, tree, yearKey, file):
    if tree.findall(".//div[@type='chapter']"):
        chaps = tree.findall(".//div[@type='chapter']")
        ext1=len(chaps[0].findall(".//word"))
        ext_dict[yearKey].append(ext1)
        if ext1==0:
            print ("Problem (first chap) with file : "+file)
    return ext_dict

# %%
def num_ent_first (ext_ent_dict, tree, yearKey, file):
    if tree.findall(".//div[@type='chapter']"):
        chaps = tree.findall(".//div[@type='chapter']")
        ext1=len(chaps[0].xpath(".//word[starts-with(@postag, 'NAME')]"))
        if (ext1>1000):
            if 'title' in chaps[0].attrib:
                print(chaps[0].attrib['title'])
            print(ext1)
        ext_ent_dict[yearKey].append(ext1)
    return ext_ent_dict

# %%
def num_last (ext_dict, tree, yearKey, file):
    if tree.findall(".//div[@type='chapter']"):
        chaps = tree.findall(".//div[@type='chapter']")
        ext2=len(chaps[len(chaps)-1].findall(".//word"))
        ext_dict[yearKey].append(ext2)
        if ext2==0:
            print ("Problem (last chap) with file : "+file)
    return ext_dict

# %%
def num_ent_last (ext_ent_dict, tree, yearKey, file):
    if tree.findall(".//div[@type='chapter']"):
        chaps = tree.findall(".//div[@type='chapter']")
        ext1=len(chaps[len(chaps)-1].xpath(".//word[starts-with(@postag, 'NAME')]"))
        ext_ent_dict[yearKey].append(ext1)
    return ext_ent_dict

# %%
def words_for_plot (words_dict, plot_words):
    for year in sorted(words_dict.keys()):
        if len(words_dict[year])>0:
        #moyenne nombre de mots par année
            plot_words[year]=sum(words_dict[year])/len(words_dict[year])
    return plot_words

# %%
def divs_for_plot (divs_dict, plot_divs, hierarchy):
    for year in sorted(divs_dict.keys()):
        plot_divs[year]=divs_dict[year].count(hierarchy)
    return plot_divs

# %%
def by_attribute (list_of_files, path_in, lxml_string):
    filtered=list()
    for tmpFile in list_of_files:

        fullPath=path_in+tmpFile.replace("/",":")

        if os.path.isfile(fullPath):
            tree=etree.parse(fullPath)
        
            if tree.findall(lxml_string):
                filtered.append(tmpFile)
    return filtered

# %%
def by_element_value (list_of_files, path_in, lxml_string, value_to_check):
    filtered=list()
    for tmpFile in list_of_files:

        fullPath=path_in+tmpFile.replace("/",":")

        if os.path.isfile(fullPath):
            tree=etree.parse(fullPath)
        
            if tree.findall(lxml_string):
                for elem in tree.findall(lxml_string):
                    if elem.text and value_to_check in elem.text:
                        filtered.append(tmpFile)
    return filtered

# %%
def by_name (list_of_files, path_in, author):
    files_by_author=list()
    for tmpFile in list_of_files:
        fullPath=path_in+tmpFile.replace("/",":")
        if os.path.isfile(fullPath):
            result = re.search('[0-9]{4}(.*)_', tmpFile)
            name= result.group(1)
            if author in name:
                files_by_author.append(tmpFile)
    return files_by_author

# %%
# %matplotlib inline
path_to_folder='/home/odysseus/Bureau/ANR/corpus/tagged_rest/'
#path_to_folder='/home/odysseus/Bureau/ANR/romans/'
authors=['_Dumas','_Zola','_Maupassant','_Sand-G',"_Ponson","_Flaubert"]

print("Statistiques globales : ")
files_list=fnmatch.filter(os.listdir(path_to_folder), '*.xml')

#stats_authors=OrderedDict()
#for author in authors:
    #names=by_name(files_list, path_to_folder,author)
    #stats_authors[author]=process_files(names, path_to_folder)
#pickle.dump(stats_authors, open("stats_authors","wb"))
    
stats_global=process_files(files_list, path_to_folder)

#canon_list=by_attribute(files_list, path_to_folder,".//profileDesc[@tag='non-canon']")
#stats_canon=process_files(canon_list, path_to_folder)

#genre_list=by_element_value(files_list, path_to_folder,".//term","populaire")
#stats_genre=process_files(genre_list, path_to_folder)

pickle.dump(stats_global, open("stats_rest","wb"))
#pickle.dump(stats_canon, open("stats_rest_non-canon","wb"))
#pickle.dump(stats_genre, open("stats_rest_populaire","wb"))
# Out:
# Statistiques globales :
# Processing 822 files. Please wait, this might take some time.
#
# Processing file 1858_Segur-comtesse-de_Les-Malheurs-de-Sophie.xml
#
# Processing file 1850_Dumas-Alexandre_Le-Vicomte-de-Bragelonne.xml
#
# Processing file 2014_Volodine-Antoine_Terminus-radieux.xml
#
# Processing file 1909_Boylesve-Rene_La-jeune-fille-bien-elevee.xml
#
# Processing file 1872_Zola-Emile_La-curee.xml
#
# Processing file 1861_Erckmann-Chatrian_Confidences-d-un-joueur-de-clarinette.xml
#
# Processing file 1920_Toulet-Paul-Jean_La-jeune-fille-verte-roman.xml
#
# Processing file 1961_Troyat-Henri_La-gloire-des-vaincus.xml
#
# Processing file 1888_Malot-Hector_Conscience.xml
#
# Processing file 1944_Aragon-Louis_Aurelien.xml
#
# Processing file 1951_Rebatet-Lucien_Les-Deux-Etendards.xml
#
# Processing file 1991_Bauchau-Henry_Diotime-et-les-lions.xml
#
# Processing file 1847_Collin-de-Plancy-Jacques-Albin-Simon-(1794-1881)_Legende-du-Juif-Errant.xml
#
# Processing file 1861_Rocca-Maria-della-(nee-Embden-Heine-pseud-Camille-Henry-Princesse)_Le-Roman-d-une-femme-laide.xml
#
# Processing file 1977_Ernaux-Annie_Ce-qu-ils-disent-ou-rien.xml
#
# Processing file 1843_Doutre-Joseph_Les-fiances-de-1812.xml
#
# Processing file 1949_Simenon-Georges_Mon-ami-Maigret.xml
#
# Processing file 1897_Roussel-Raymond_La-doublure.xml
#
# Processing file 1994_Rolin-Olivier_Port-Soudan.xml
#
# Processing file 1921_Leroux-Gaston_Cheri-Bibi-et-Cecily.xml
#
# Processing file 1972_A.D.G._Cradoque-s-band.xml
#
# Processing file 1880_Karr-Alphonse_Bourdonnements.xml
# BOURDONNEMENTS
# 1352
#
# Processing file 1847_Sandeau-Jules_Mademoiselle-de-la-Seigli__re-Volume-1.xml
#
# Processing file 1909_Giraudoux-Jean_Provinciales.xml
#
# Processing file 1959_Sarraute-Nathalie_Le-Planetarium.xml
#
# Processing file 1994_Chevillard-Eric_Prehistoire.xml
#
# Processing file 1845_Merimee-Prosper_Carmen.xml
#
# Processing file 1931_Saint-Exupery-Antoine-de_Vol-de-nuit.xml
#
# Processing file 1877_Goncourt-Edmond-et-Jules-de_La-fille-Elisa.xml
#
# Processing file 1935_Duhamel-Georges_La-nuit-de-la-Saint-Jean.xml
#
# Processing file 1942_Vercors_Le-silence-de-la-mer.xml
#
# Processing file 1930_Galopin-Arnould_Le-sergent-Bucaille.xml
#
# Processing file 1929_Dabit-Eugene_L-Hotel-du-Nord.xml
#
# Processing file 1865_Erckmann-Chatrian_Histoire-d-un-homme-du-peuple.xml
#
# Processing file 1907_Segalen-Victor_Les-Immemoriaux.xml
#
# Processing file 1909_Leblanc-Maurice_L-Aiguille-creuse.xml
#
# Processing file 1999_Echenoz-Jean_Je-m-en-vais.xml
#
# Processing file 1962_Simenon-Georges_Maigret-et-les-braves-gens.xml
#
# Processing file 1863_Fromentin-Eugene_Dominique.xml
#
# Processing file 1987_Chevillard-Eric_Mourir-m-enrhume.xml
#
# Processing file 2010_Volodine-Andoine-(pseudonyme--Lutz-Bassmann)_Les-aigles-puent.xml
#
# Processing file 2001_Rufin-Jean-Christophe_Rouge-Bresil.xml
#
# Processing file 1967_Perec-Georges_Un-homme-qui-dort.xml
#
# Processing file 1909_Colette_L-Ingenue-libertine.xml
#
# Processing file 1886_Loti-Pierre_Pecheur-d-Islande.xml
#
# Processing file 1899_Adam-Paul_La-Force.xml
#
# Processing file 1926_Mac-Orlan-Pierre_Les-clients-du-Bon-Chien-Jaune.xml
#
# Processing file 1967_Simenon-Georges_Le-voleur-de-Maigret.xml
#
# Processing file 1848_Balzac-Honore-de_Les-Parents-pauvres-La-Cousine-BetteFC.xml
#
# Processing file 1957_Pagnol-Marcel_Le-Chateau-de-ma-mere.xml
#
# Processing file 1956_Thomas-Henri_La-nuit-de-Londres.xml
#
# Processing file 1890_Pont-Jest-Rene-de_Le-Fleuve-des-perles-(L-araignee-Rouge).xml
#
# Processing file 1887_Verne-Jules_Nord-contre-Sud.xml
#
# Processing file 2002_Rolin-Olivier_Tigre-en-papier.xml
#
# Processing file 1881_Verne-Jules-_La-Jangada-huit-cent-lieues-sur-l-Amazone].xml
# Premier épisode
# 2296
#
# Processing file 1954_Cohen-Albert_Le-livre-de-ma-mere.xml
#
# Processing file 1923_Malot-Hector_Romain-Kalbris.xml
#
# Processing file 1995_Bergounioux-Pierre_Miette.xml
#
# Processing file 1947_Antelme-Robert_l-espece-humaine.xml
#
# Processing file 1955_San-Antonio_Le-fil-a-couper-le-beurre.xml
#
# Processing file 1912_Loti-Pierre_Un-pelerin-d-Angkor.xml
#
# Processing file 1919_Bazin-Rene_Les-Nouveaux-Oberle.xml
#
# Processing file 1891_Huysmans-Joris-Karl_La-bas.xml
#
# Processing file 1949_San-Antonio_Reglez-lui-son-compte-.xml
#
# Processing file 1933_Leblanc-Maurice_La-femme-aux-deux-sourires.xml
#
# Processing file 1892_Loti-Pierre_Fantome-d-Orient.xml
#
# Processing file 1944_Celine-Louis-Ferdinand_Guignol-s-band.xml
#
# Processing file 1840_Merimee-Prosper_Colomba.xml
#
# Processing file 1902_Loti-Pierre_Les-derniers-jours-de-Pekin.xml
#
# Processing file 2010_Gavalda-Anna_Desordre-et-Sentiments.xml
#
# Processing file 1980_Siniac-Pierre_L-unijambiste-de-la-cote-284.xml
#
# Processing file 1983_Ernaux-Annie_La-place.xml
#
# Processing file 1943_Barjavel-Rene_Ravage.xml
#
# Processing file 1886_Valles-Jules_L-Insurge.xml
#
# Processing file 1879_Huysmans-Joris-Karl_Les-soeurs-Vatard.xml
#
# Processing file 1923_Chateaubriant-Alphonse-de_La-Briere.xml
#
# Processing file 1843_Feval-Paul-(pere)_Le-loup-blanc.xml
#
# Processing file 2012_Chandernagor-Françoise_Les-Dames-de-Rome.xml
#
# Processing file 1858_Veuillot-Louis_L-Honnete-femme.xml
#
# Processing file 1870_Ponson-du-Terrail-Pierre_Rocambole-La-Corde-du-pendu-Tome-I--La-Corde-du-pendu.xml
#
# Processing file 1996_Rolin-Jean_L-Organisation.xml
#
# Processing file 1997_Bergounioux-Pierre_L-empreinte.xml
#
# Processing file 1961_San-Antonio_San-Antonio-chez-les-Mac.xml
#
# Processing file 1892_Colomb-Josephine_Les-Conquetes-d-Hermine.xml
#
# Processing file 1913_Proust-Marcel_Du-cote-de-chez-Swann-A-la-recherche-du-temps-perdu.xml
#
# Processing file 1881_France-Anatole_Le-crime-de-Sylvestre-Bonnard.xml
#
# Processing file 1858_Gautier-Theophile_Le-roman-de-la-momie.xml
#
# Processing file 1977_Simonin-Albert_Confessions-d-un-enfant-de-La-Chapelle.xml
#
# Processing file 1922_Bordeaux-Henry_Le-fantome-de-la-rue-Michel-Ange.xml
#
# Processing file 1986_Daeninckx-Didier_Le-bourreau-et-son-double.xml
#
# Processing file 1886_Malot-Hector_Baccara.xml
#
# Processing file 1882_Zola-Emile_Pot-Bouille.xml
#
# Processing file 1951_Giono-Jean_Le-Hussard-sur-le-toit.xml
#
# Processing file 1909_Leroux-Gaston_Le-parfum-de-la-Dame-en-noir.xml
#
# Processing file 1934_Yourcenar-Marguerite_Denier-du-reve.xml
#
# Processing file 1893_Lemonnier-Camille_L-Homme-qui-tue-les-femmes.xml
#
# Processing file 1959_Sagan-Françoise_Aimez-vous-Brahms.xml
#
# Processing file 1937_Bernanos-Georges_Nouvelle-histoire-de-Mouchette.xml
#
# Processing file 1967_Tournier-Michel_Vendredi-ou-les-limbes-du-Pacifique.xml
#
# Processing file 1920_Colette_Cheri.xml
#
# Processing file 1858_Feuillet-Octave_Le-roman-d-un-jeune-homme-pauvre.xml
#
# Processing file 1860_Assollant-Alfred_Histoire-fantastique-du-celebre-Pierrot.xml
#
# Processing file 2013_Darrieussecq-Marie_Il-faut-beaucoup-aimer-les-hommes.xml
#
# Processing file 1845_Dumas-Alexandre_Le-Comte-de-Monte-Cristo.xml
#
# Processing file 2006_Vargas-Fred_Dans-les-bois-eternels.xml
#
# Processing file 1866_Gaboriau-Emile_L-affaire-Lerouge.xml
#
# Processing file 1977_Pagnol-Marcel_Souvenirs-d-enfance-IV-Le-temps-des-amours.xml
#
# Processing file 1916_Barbusse-Henri_Le-Feu.xml
#
# Processing file 1878_Malot-Hector_Cara.xml
#
# Processing file 1843_Sand-George_Consuelo.xml
#
# Processing file 2000_Carrere-Emmanuel_L-adversaire.xml
#
# Processing file 1975_Ajar-Emile-Gary-Romain_La-Vie-Devant-Soi.xml
#
# Processing file 1934_Le-Faure-Georges_Le-brigadier-Floridor.xml
#
# Processing file 1933_Colette_La-Chatte.xml
#
# Processing file 1881_Cherbuliez-Victor_Noirs-et-Rouges-par-Victor-Cherbuliez-(1881).xml
#
# Processing file 1878_Houssaye-Arsene_Arsene-Houssaye-Les-Larmes-de-Jeanne-histoire-parisienne-(1878).xml
#
# Processing file 1940_Martin-du-Gard-Roger_Les-Thibault-Tome-VIII-Epilogue.xml
#
# Processing file 1895_France-Anatole_Le-Jardin-d-Epicure.xml
#
# Processing file 1941_Morand-Paul_L-homme-presse.xml
#
# Processing file 2014_Modiano-Patrick_Pour-que-tu-ne-te-perdes-pas-dans-le-quartier.xml
#
# Processing file 1843_Balzac-Honore-de_Illusions-perdues.xml
#
# Processing file 1846_Feval-Paul-(pere)_Le-Fils-du-diable-Tome-I.xml
#
# Processing file 2001_Simon-Claude_Le-tramway.xml
#
# Processing file 2000_Djian-Philippe_Vers-chez-les-blancs.xml
#
# Processing file 1972_Giono-Jean_Les-recits-de-la-demi-brigade.xml
#
# Processing file 1936_Celine-Louis-Ferdinand_Mort-a-credit.xml
#
# Processing file 1958_Duras-Marguerite_Moderato-cantabile.xml
# Processing file 2008_Riboulet-Mathieu_L-Amant-Des-Morts.xml
#
# Processing file 1908_Leroux-Gaston_Le-mystere-de-la-chambre-jaune.xml
#
# Processing file 1885_Zola-Emile_Germinal.xml
#
# Processing file 1978_Perec-Georges_La-Vie-mode-d-emploi.xml
#
# Processing file 1894_Rachilde_Le-Demon-de-l-Absurde.xml
#
# Processing file 1866_Feval-Paul-(pere)_L-avaleur-de-sabres-Les-Habits-Noirs-Tome-VI.xml
#
# Processing file 1857_Feval-Paul-(pere)_Les-Errants-de-la-nuit.xml
#
# Processing file 1907_Apollinaire-Guillaume_Les-Onze-mille-verges-ou-les-Amours-d-un-hospodar.xml
#
# Processing file 2006_Quignard-Pascal_Villa-Amalia.xml
#
# Processing file 1877_Zola-Emile_L-assomoir.xml
#
# Processing file 1876_Malot-Hector_L-Auberge-du-monde-Tome-1.xml
#
# Processing file 1952_Calet-Henri_Un-Grand-Voyage.xml
#
# Processing file 2014_Rouaud-Jean_Un-peu-la-guerre.xml
#
# Processing file 1908_Dhanys-Marcel_Marcel-Dhanys-Le-Roman-du-grand-Conde-Edition-3-(1908).xml
#
# Processing file 1858_Segur-comtesse-de_Les-Petites-Filles-Modeles.xml
#
# Processing file 1869_Stolz-Madame-de_La-Maison-roulante.xml
#
# Processing file 1894_Louÿs-Pierre_Les-chansons-de-Bilitis.xml
#
# Processing file 1961_San-Antonio_Ne-mangez-pas-la-consigne.xml
#
# Processing file 1930_Malraux-Andre_La-voie-royale.xml
#
# Processing file 1943_Saint-Exupery-Antoine-de_Le-petit-prince.xml
#
# Processing file 1973_Vautrin-Jean_a-Bulletins-Rouges.xml
#
# Processing file 1910_Roussel-Raymond_Impressions-d-Afrique.xml
#
# Processing file 1922_Rolland-Romain_L-ame-enchantee-Annette-et-Sylvie-Volume-1.xml
#
# Processing file 1920_Zevaco-Michel_Le-Pre-aux-clercs.xml
#
# Processing file 1926_Rosny-aine-J-H_La-Femme-disparue.xml
#
# Processing file 1854_Barbey-d-Aurevilly-Jules_L-ensorcelee.xml
#
# Processing file 1910_Ivoi-Paul-d-_Millionnaire-malgre-lui-(tome-1).xml
#
# Processing file 1899_Mirbeau-Octave_Le-Jardin-des-supplices.xml
#
# Processing file 1933_Malraux-Andre_La-Condition-Humaine.xml
#
# Processing file 1931_Nizan-Paul_Aden-Arabie.xml
#
# Processing file 1880_Ulbach-Louis_Le-Crime-de-Martial-par-Louis-Ulbach-(1880).xml
#
# Processing file 1844_L-Ecuyer-Eugene_Un-episode-de-la-vie-d-un-faux-devot.xml
#
# Processing file 1875_Verne-Jules_L-Ile-Mysterieuse.xml
# Partie 1.
# 2142
#
# Processing file 2010_Kerangal-Maylis-de_Naissance-d-un-pont.xml
#
# Processing file 1999_Volodine-Antoine_Des-anges-mineurs.xml
#
# Processing file 1863_Farrenc-Cesarie_La-jalousie.xml
#
# Processing file 1984_Duras-Marguerite_L-Amant.xml
#
# Processing file 1974_Yourcenar-Marguerite_Souvenirs-pieux.xml
#
# Processing file 1892_Verne-Jules_Le-Chateau-des-Carpathes.xml
#
# Processing file 2014_Kerangal-Maylis-de_Reparer-les-vivants.xml
#
# Processing file 1868_Ponson-du-Terrail-Pierre_Rocambole-Les-Miseres-de-Londre-Tome-I-La-Nourisseuse-d-enfants.xml
#
# Processing file 1950_Fourre-Maurice_La-Nuit-du-Rose-Hotel.xml
#
# Processing file 1963_Pagnol-Marcel_Jean-De-Florette.xml
#
# Processing file 1945_Gracq-Julien_Un-beau-tenebreux.xml
#
# Processing file 1869_Gaboriau-Emile_Monsieur-Lecoq-I.xml
#
# Processing file 1913_Psichari-Ernest_L-appel-des-armes-(1945).xml
#
# Processing file 1848_Sand-George_François-le-champi.xml
#
# Processing file 2011_Quignard-Pascal_Les-solidarites-mysterieuses.xml
#
# Processing file 1857_Feval-Paul-(pere)_Le-Bossu.xml
#
# Processing file 2012_Jouet-Jacques_La-seule-fois-de-l-amour.xml
#
# Processing file 2001_Rouaud-Jean_La-desincarnation.xml
#
# Processing file 1970_Tournier-Michel_Le-Roi-des-Aulnes.xml
#
# Processing file 1971_Simenon-Georges_Maigret-et-l-homme-tout-seul.xml
#
# Processing file 1972_Gary-Romain_Europa.xml
#
# Processing file 1945_Calet-Henri_Le-Bouquet.xml
#
# Processing file 1987_Echenoz-Jean_Equipee-malaise.xml
#
# Processing file 1902_Lesueur-Daniel_Le-meurtre-d-une-ame.xml
#
# Processing file 1975_Simon-Claude_Leçon-De-Choses.xml
#
# Processing file 1866_Valles-Jules_Les-Refractaires.xml
#
# Processing file 1859_Mallefille-Felicien_Monsieur-Corbeau.xml
#
# Processing file 1875_Cherbuliez-Victor_Miss-Rovel.xml
#
# Processing file 1896_Loti-Pierre_Ramuntcho.xml
#
# Processing file 2015_Enard-Mathias_Boussole.xml
# Problem (first chap) with file : 2015_Enard-Mathias_Boussole.xml
# Problem (last chap) with file : 2015_Enard-Mathias_Boussole.xml
#
# Processing file 1960_Simon-Claude_La-Route-des-Flandres.xml
#
# Processing file 1944_Camus-Albert_Le-premier-homme.xml
#
# Processing file 1932_Leblanc-Maurice_De-minuit-a-sept-heures.xml
#
# Processing file 1912_Courteline-Georges_Les-Linottes.xml
#
# Processing file 1988_Michon-Pierre_Vie-de-Joseph-Roulin.xml
#
# Processing file 1864_Bastide-Jenny_Le-monstre.xml
#
# Processing file 1956_Malet-Leo_Corrida-aux-Champs-Elysees.xml
#
# Processing file 1933_Duhamel-Georges_Le-notaire-du-Havre.xml
#
# Processing file 1924_Radiguet-Raymond_Le-Bal-du-comte-d-Orgel.xml
#
# Processing file 2012_Modiano-Patrick_L-herbe-des-nuits.xml
#
# Processing file 1923_Le-Rouge-Gustave_Les-Aventures-de-Todd-Marvel-detective-milliardaire.xml
#
# Processing file 1847_Richomme-Fanny-Claudet-Mme-Prosper_Grain-de-sable-ou-le-Sorcier-d-Altenbourg.xml
#
# Processing file 1942_Camus-Albert_L-etranger.xml
#
# Processing file 1856_Gautier-Theophile_Avatar.xml
#
# Processing file 1997_Des-Forets-Rene-Louis_Ostinato.xml
#
# Processing file 1951_Beckett-Samuel_Molloy.xml
#
# Processing file 2002_Volodine-Antoine_Dondog.xml
#
# Processing file 1923_Colette_Le-Ble-en-herbe.xml
#
# Processing file 1920_Mauriac-François_La-chair-et-le-sang.xml
#
# Processing file 1992_Le-Linda_Les-Evangiles-du-crime.xml
#
# Processing file 1841_Barbey-d-Aurevilly-Jules_L-amour-impossible.xml
#
# Processing file 1962_Troyat-Henri_Les-Dames-de-Siberie.xml
#
# Processing file 1909_Barres-Maurice_Colette-Baudoche.xml
#
# Processing file 1862_Malot-Hector_Les-Amants.xml
#
# Processing file 1888_Larmandie-Leonce-de_Excelsior-Roman-parisien.xml
#
# Processing file 1894_Vanderem-Fernand_La-Cendre-Roman.xml
#
# Processing file 1868_Perret-Paul_La-Parisienne.xml
#
# Processing file 1853_Desnoiresterres-Gustave_Un-amour-en-diligence.xml
#
# Processing file 1899_Boylesve-Rene_Mademoiselle-Clocque.xml
#
# Processing file 1965_De-Villiers-Gerard_SAS-a-Istanbul.xml
#
# Processing file 1968_Gary-Romain_La-Tete-coupable.xml
#
# Processing file 1844_Sue-Eugene_Le-juif-errant-tome-I.xml
#
# Processing file 1982_Le-Clezio-Jean-Marie-Gustave_La-ronde-et-autres-faits-divers.xml
#
# Processing file 1927_Green-Julien_Adrienne-Mesurat.xml
#
# Processing file 1875_Zola-Emile_La-faute-de-l-abbe-Mouret.xml
#
# Processing file 1857_Soulie-Frederic_Le-Magnetiseur.xml
#
# Processing file 1880_Zola-Emile_Nana.xml
#
# Processing file 1975_Deon-Michel_Le-Jeune-homme-vert.xml
#
# Processing file 1913_Gourmont-Remy-de_La-petite-ville.xml
#
# Processing file 2000_Gailly-Christian_Nuage-rouge.xml
#
# Processing file 1922_Martin-du-Gard-Roger_Les-Thibault-Tome-I-Le-Cahier-gris.xml
#
# Processing file 1974_Ajar-Emile-Gary-Romain_Gros-Calin.xml
#
# Processing file 1894_Tissot-Victor_Simone-Histoire-d-une-jeune-fille-moderne.xml
#
# Processing file 2009_Toussaint-Jean-Philippe_La-Verite-sur-Marie.xml
#
# Processing file 1950_Nimier-Roger_Le-Hussard-Bleu.xml
#
# Processing file 1938_Nizan-Paul_La-Conspiration.xml
#
# Processing file 1994_Houellebecq-Michel_Extension-du-domaine-de-la-lutte.xml
#
# Processing file 2009_Michon-Pierre_Les-Onze.xml
#
# Processing file 2003_Darrieussecq-Marie_White.xml
#
# Processing file 1843_Tillier-Claude_Mon-oncle-Benjamin.xml
#
# Processing file 2011_Millet-Richard_La-Fiancee-libanaise.xml
#
# Processing file 1891_Metenier-Oscar_Le-gorille-Roman-parisien.xml
#
# Processing file 2014_Louis-Edouard_En-finir-avec-Eddy-Bellegueule.xml
#
# Processing file 1994_Grange-Jean-Christophe_Le-vol-des-cigognes.xml
#
# Processing file 1919_Dumur-Louis_Nach-Paris-Roman.xml
#
# Processing file 1881_Valles-Jules_Le-Bachelier.xml
#
# Processing file 1843_Sue-Eugene_Les-Mystere-de-Paris-Tome-IV.xml
#
# Processing file 1896_France-Anatole_L-orme-du-Mail.xml
#
# Processing file 1981_Simon-Claude_Les-Georgiques.xml
#
# Processing file 1987_Villard-Marc_Rebelles-de-la-nuit.xml
#
# Processing file 1988_Yourcenar-Marguerite_Quoi-L-Eternite.xml
#
# Processing file 1991_Michon-Pierre_Rimbaud-le-fils.xml
#
# Processing file 1888_Mirbeau-Octave_L-Abbe-Jules.xml
#
# Processing file 1923_Istrati-Panait_Les-recits-d-Adrien-Zograffi-I.xml
#
# Processing file 1993_Villard-Marc_La-porte-de-derriere.xml
#
# Processing file 1948_Barjavel-Rene_Le-diable-l-emporte.xml
#
# Processing file 1850_Dumas-Alexandre_La-Tulipe-noire.xml
# Processing file 1910_Audoux-Marguerite_Marie-Claire.xml
#
# Processing file 1890_Ohnet-Georges_L-Ame-de-Pierre.xml
#
# Processing file 1845_Walsh-Joseph-Alexis_Les-Veillees-de-voyage.xml
#
# Processing file 1921_Bourget-Paul_L-Ecuyere.xml
#
# Processing file 1968_Simonin-Albert_Le-Hotu.xml
#
# Processing file 1984_Daeninckx-Didier_Le-der-des-ders.xml
#
# Processing file 1853_Chavannes-de-La-Giraudiere-Hippolyte-de_Les-Petits-voyageurs-en-Californie.xml
#
# Processing file 2013_Thiery-Danielle_La-petite-fille-de-Marie-Gare.xml
#
# Processing file 1970_Simenon-Georges_La-folle-de-Maigret.xml
#
# Processing file 1932_Lallier-Joseph_Le-spectre-menaçant.xml
#
# Processing file 2015_Despentes-Virginie_Vernon-Subutex-T1.xml
#
# Processing file 1870_Daudet-Alphonse_Le-Nabab.xml
#
# Processing file 1865_Goncourt-Edmond-et-Jules-de_Germinie-Lacerteux.xml
#
# Processing file 1936_Bernanos-Georges_Le-Journal-d-un-cure-de-campagne.xml
#
# Processing file 1998_Daeninckx-Didier_Cannibale.xml
#
# Processing file 1930_Giono-Jean_Regain.xml
#
# Processing file 1929_Nemirovsky-Irene_David-Golder.xml
#
# Processing file 1997_Gailly-Christian_Les-Evades.xml
#
# Processing file 1947_Vian-Boris_L-ecume-des-jours.xml
#
# Processing file 1881_Daudet-Alphonse_Sapho.xml
#
# Processing file 1911_Leroux-Gaston_L-homme-qui-a-vu-le-diable.xml
#
# Processing file 1906_Loti-Pierre_Les-Desenchantees.xml
#
# Processing file 1995_Carrere-Emmanuel_La-classe-de-neige.xml
#
# Processing file 1941_Leblanc-Maurice_Les-Milliards-d-Arsene-Lupin.xml
#
# Processing file 1907_Bazin-Rene_Le-ble-qui-leve.xml
#
# Processing file 1971_Laurent-Jacques_Les-betises.xml
#
# Processing file 1845_Sand-George_Le-meunier-d-Angibault.xml
#
# Processing file 1864_ Verne-Jules_Voyage-au-centre-de-la-Terre.xml
#
# Processing file 2013_Rolin-Jean_Ormuz.xml
#
# Processing file 1914_Roussel-Raymond_Locus-Solus.xml
#
# Processing file 1887_Guy-de-Maupassant_Pierre-et-Jean.xml
#
# Processing file 1933_Leblanc-Maurice_Victor-de-la-Brigade-mondaine.xml
#
# Processing file 1911_Apollinaire-Guillaume_Les-exploits-d-un-jeune-don-Juan.xml
#
# Processing file 1998_Rouaud-Jean_Pour-vos-cadeaux.xml
#
# Processing file 1929_Yourcenar-Marguerite_Alexis-ou-le-Traite-du-Vain-Combat-Le-Coup-de-Grace.xml
#
# Processing file 1851_Sand-George_Le-chateau-des-Desertes.xml
#
# Processing file 1913_Mauriac-François_L-enfant-charge-de-chaines.xml
#
# Processing file 1997_Modiano-Patrick_Dora-Bruder.xml
#
# Processing file 2004_Bouraoui-Nina_Poupee-Bella.xml
#
# Processing file 1947_Simon-Claude_La-corde-raide.xml
#
# Processing file 1855_Nerval-Gerard-de_Aurelia.xml
#
# Processing file 1864_Dumas-Alexandre_La-San-Felice.xml
#
# Processing file 1880_Boisgobey-Fortune-du_Le-crime-de-l-omnibus.xml
#
# Processing file 1953_Simenon-Georges_Maigret-a-peur.xml
#
# Processing file 1855_Reybaud-Louis_La-vie-de-l-employe.xml
#
# Processing file 2010_Despentes-Virginie_Apocalypse-bebe.xml
#
# Processing file 1993_Chevillard-Eric_La-nebuleuse-du-Crabe.xml
#
# Processing file 1866_Hugo-Victor_Les-travailleurs-de-la-mer.xml
#
# Processing file 2012_Echenoz-Jean_14.xml
#
# Processing file 1993_Carrere-Emmanuel_je-suis-vivant-et-vous-etes-morts.xml
#
# Processing file 1969_Montherlant-Henry-de_Les-garçons.xml
#
# Processing file 1910_Leroux-Gaston_Le-fantome-de-l-Opera.xml
#
# Processing file 1941_Blanchot-Maurice_Thomas-l-Obscur.xml
#
# Processing file 1989_Gailly-Christian_K.622.xml
#
# Processing file 2006_Jourde-Pierre_L-Heure-et-l-ombre.xml
#
# Processing file 1982_Barjavel-Rene_La-Tempete.xml
#
# Processing file 1910_Rolland-Romain_Jean-Christophe-Tome-VIII-Les-amies.xml
# Page titre
# 1465
#
# Processing file 1902_Rebell-Hugues_Les-Nuits-chaudes-du-Cap-français.xml
#
# Processing file 1985_Carrere-Emmanuel_La-Moustache.xml
#
# Processing file 1853_Gozlan-Leon_Les-Vendanges.xml
#
# Processing file 2004_Grimbert-Philippe_Un-secret.xml
#
# Processing file 1953_Simonin-Albert_Touchez-pas-au-grisbi.xml
#
# Processing file 1970_Deon-Michel_Les-poneys-sauvages.xml
#
# Processing file 1844_Dumas-Alexandre_Les-Trois-Mousquetaires.xml
#
# Processing file 1955_Dhotel-Andre_Le-pays-ou-l-on-n-arrive-jamais.xml
#
# Processing file 1901_Colette_Claudine-a-Paris.xml
#
# Processing file 1922_Margueritte-Victor_La-garçonne.xml
#
# Processing file 2008_Kerangal-Maylis-de_Corniche-Kennedy.xml
#
# Processing file 1899_Le-Rouge-Gustave_La-Conspiration-des-milliardaires-Tome-I.xml
#
# Processing file 1939_Leiris-Michel_L-Age-d-homme.xml
#
# Processing file 1989_Villard-Marc_La-dame-est-une-trainee.xml
#
# Processing file 1920_Boylesve-Rene_Le-carrosse-aux-deux-lezards-verts.xml
#
# Processing file 1947_Renard-Maurice_Le-Maitre-de-la-lumiere.xml
#
# Processing file 1929_Giono-Jean_Colline.xml
#
# Processing file 1855_Gerard-Jules_La-Chasse-au-lion.xml
#
# Processing file 2008_Ernaux-Annie_Les-annees.xml
#
# Processing file 1941_Jaloux-Edmond_Les-Visiteurs.xml
#
# Processing file 2010_Bauchau-Henry_Deluge.xml
#
# Processing file 2016_Rolin-Olivier_Veracruz.xml
#
# Processing file 1878_Assollant-Alfred_Le-plus-hardi-des-gueux-par-Alfred-Assollant-(1878).xml
#
# Processing file 2016_Ernaux-Annie_Memoire-de-fille.xml
#
# Processing file 1984_Modiano-Patrick_Quartier-perdu.xml
#
# Processing file 1930_Lallier-Joseph_Angeline-Guillou.xml
#
# Processing file 1957_Pagnol-Marcel_La-Gloire-de-mon-pere.xml
#
# Processing file 1968_Dhotel-Andre_L-Enfant-qui-disait-n-importe-quoi.xml
#
# Processing file 1947_Camus-Albert_La-peste.xml
#
# Processing file 1874_Flaubert-Gustave_La-tentation-de-saint-Antoine.xml
#
# Processing file 1900_Le-Roy-Eugene_Jacquou-Le-Croquant.xml
#
# Processing file 1905_Le-Roy-Eugene_Le-moulin-du-Frau.xml
# Problem (first chap) with file : 1905_Le-Roy-Eugene_Le-moulin-du-Frau.xml
#
# Processing file 2001_Nothomb-Amelie_Cosmetique-de-l-ennemi.xml
#
# Processing file 1845_Viel-Castel-Horace-de_Archambaud-de-Comborn.xml
#
# Processing file 1949_Blondin-Antoine_L-Europe-buissoniere.xml
#
# Processing file 1906_Bordeaux-Henry_Les-Roquevillard.xml
#
# Processing file 1904_Loti-Pierre_Vers-Ispahan.xml
#
# Processing file 2002_Ernaux-Annie_L-Occupation.xml
#
# Processing file 1919_Giraudoux-Jean_Elpenor-par-Jean-Giraudoux-(1919).xml
#
# Processing file 1874_Beaugrand-Honore_Anita-souvenirs-d-un-contre-guerillas.xml
#
# Processing file 1905_Verne-Jules_Le-Phare-du-Bout-du-Monde.xml
#
# Processing file 1958_Troyat-Henri_Les-compagnons-du-coquelicot.xml
#
# Processing file 1994_Volodine-Antoine_Le-nom-des-singes.xml
#
# Processing file 1881_Huysmans-Joris-Karl_En-menage-Edition-2-(1881).xml
#
# Processing file 1854_Nerval-Gerard-de_Promenades-et-souvenirs.xml
#
# Processing file 1878_Houssaye-Arsene_Arsene-Houssaye-Les-Trois-duchesses-Tome-1-(1878).xml
#
# Processing file 1910_Zevaco-Michel_Triboulet.xml
#
# Processing file 1913_Lermina-Jules_L-effrayante-aventure.xml
#
# Processing file 1961_Robbe-Grillet-Alain_L-Annee-derniere-a-Marienbad.xml
#
# Processing file 1987_Rolin-Olivier_Bar-des-flots-noirs.xml
#
# Processing file 1983_Echenoz-Jean_Cherokee.xml
#
# Processing file 1882_Toudouze-Gustave_Gustave-Toudouze-La-Seductrice-roman-parisien-(1882).xml
#
# Processing file 1980_A.D.G._Pour-venger-Pepere.xml
#
# Processing file 1911_Larbaud-Valery_Fermina-Marquez.xml
#
# Processing file 1846_Balzac-Honore-de_Une-tenebreuse-affaire.xml
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-7b55fe8b34ed> in <module>()
#      13 #pickle.dump(stats_authors, open("stats_authors","wb"))
#      14
# ---> 15 stats_global=process_files(files_list, path_to_folder)
#      16
#      17 #canon_list=by_attribute(files_list, path_to_folder,".//profileDesc[@tag='non-canon']")
#
# <ipython-input-47-ecb10fc8fb8b> in process_files(list_of_files, path_in)
#      50             last_dict=num_last(last_dict, tree, yearKey, tmpFile)
#      51
# ---> 52             first_ent_dict=num_ent_first(first_ent_dict, tree, yearKey, tmpFile)
#      53
#      54             last_ent_dict=num_ent_last(last_ent_dict, tree, yearKey, tmpFile)
#
# <ipython-input-55-4e81d03b8a09> in num_ent_first(ext_ent_dict, tree, yearKey, file)
#       4         ext1=len(chaps[0].xpath(".//word[starts-with(@postag, 'NAME')]"))
#       5         if (ext1>1000):
# ----> 6             print(chaps[0].attrib['title'])
#       7             print(ext1)
#       8         ext_ent_dict[yearKey].append(ext1)
#
# src/lxml/etree.pyx in lxml.etree._Attrib.__getitem__()
#
# KeyError: 'title'

# %%
stats_global=pickle.load(open( "stats_global", "rb"))
limitsX=[1820,2000]
limitsWord=[0,50000]
limitsChap=[0,60]
sliding=10
color=['r','g']
plot_stats(stats_global["word"][0],stats_global["word"][1],limitsX,limitsWord,sliding,color[0],"nombre de mots moyen par chapitre --Corpus Global")
plot_stats(stats_global["chapter"][0],stats_global["chapter"][1],limitsX,limitsChap,sliding,color[1],"nombre de chapitres moyen --Corpus Global")

# %%
stats_canon=pickle.load(open( "stats_global_canon", "rb"))
limitsX=[1800,2000]
limitsWord=[0,60000]
limitsChap=[0,50]
sliding=10
plot_stats(stats_canon["word"][0],stats_canon["word"][1],limitsX,limitsWord,sliding,"nombre de mots moyen par chapitre pour le canon -- Corpus Global")
plot_stats(stats_canon["chapter"][0],stats_canon["chapter"][1],limitsX,limitsChap,sliding,"nombre de chapitres moyen dans le temps pour le canon -- Corpus Global")

# %%
stats_canon=pickle.load(open( "stats_global_non-canon", "rb"))
limitsX=[1800,2000]
limitsWord=[0,60000]
limitsChap=[0,50]
sliding=10
plot_stats(stats_canon["word"][0],stats_canon["word"][1],limitsX,limitsWord,sliding,"nombre de mots moyen par chapitre pour le non-canon -- Corpus Global")
plot_stats(stats_canon["chapter"][0],stats_canon["chapter"][1],limitsX,limitsChap,sliding,"nombre de chapitres moyen dans le temps pour le non-canon -- Corpus Global")

# %%
stats_canon=pickle.load(open( "stats_rest_policier", "rb"))
limitsX=[1840,1950]
limitsWord=[0,40000]
limitsChap=[0,60]
sliding=10
color=['r','g']
plot_stats(stats_canon["word"][0],stats_canon["word"][1],limitsX,limitsWord,sliding,color[1],"nombre de mots moyen par chapitre pour la littérature populaire --Corpus Global")
plot_stats(stats_canon["chapter"][0],stats_canon["chapter"][1],limitsX, limitsChap,sliding,color[0],"nombre de chapitres moyen pour la littérature populaire --Corpus Global")

# %%
stats_global=pickle.load(open( "stats_rest", "rb"))
limitsX=[1840,1950]
limitsWord=[0,40000]
limitsChap=[0,60]
sliding=5
color=['r','g']
plot_stats(stats_global["word"][0],stats_global["word"][1],limitsX,limitsWord,sliding,color[0],"nombre de mots moyen par chapitre -- Corpus Restreint")
plot_stats(stats_global["chapter"][0],stats_global["chapter"][1],limitsX,limitsChap,sliding,color[1],"nombre de chapitres moyen -- Corpus Restreint")

# %%
stats_canon=pickle.load(open( "stats_rest_canon", "rb"))
limitsX=[1840,1950]
limitsWord=[0,40000]
limitsChap=[0,60]
sliding=10
color=['r','g']
plot_stats(stats_canon["word"][0],stats_canon["word"][1],limitsX,limitsWord,sliding,color[0],"nombre de mots moyen par chapitre")
plot_stats(stats_canon["chapter"][0],stats_canon["chapter"][1],limitsX, limitsChap,sliding,color[1],"nombre de chapitres moyen dans le temps")

# %%
stats_canon=pickle.load(open( "stats_rest_non-canon", "rb"))
limitsX=[1840,1950]
limitsWord=[0,40000]
limitsChap=[0,60]
sliding=10
color=['r','g']
plot_stats(stats_canon["word"][0],stats_canon["word"][1],limitsX,limitsWord,sliding,color[0],"nombre de mots moyen par chapitre")
plot_stats(stats_canon["chapter"][0],stats_canon["chapter"][1],limitsX, limitsChap,sliding,color[1],"nombre de chapitres moyen dans le temps")

# %%
stats_canon=pickle.load(open( "stats_rest_policier", "rb"))
limitsX=[1840,1950]
limitsWord=[0,40000]
limitsChap=[0,60]
sliding=10
color=['r','g']
plot_stats(stats_canon["word"][0],stats_canon["word"][1],limitsX,limitsWord,sliding,color[1],"nombre de mots moyen par chapitre pour le policier --Corpus Restreint")
plot_stats(stats_canon["chapter"][0],stats_canon["chapter"][1],limitsX, limitsChap,sliding,color[0],"nombre de chapitres moyen pour le policier --Corpus Restreint")

# %%
stats_canon=pickle.load(open( "stats_rest_populaire", "rb"))
limitsX=[1860,1940]
limitsWord=[0,20000]
limitsChap=[0,60]
sliding=10
color=['r','g']
plot_stats(stats_canon["word"][0],stats_canon["word"][1],limitsX,limitsWord,sliding,color[1],"nombre de mots moyen par chapitre pour la littérature populaire --Corpus Restreint")
plot_stats(stats_canon["chapter"][0],stats_canon["chapter"][1],limitsX, limitsChap,sliding,color[0],"nombre de chapitres moyen pour la littérature populaire --Corpus Restreint")

# %%
stats_authors=pickle.load(open("stats_authors","rb"))
multiple_plots(stats_authors)

# %%
stats_global=pickle.load(open( "stats_rest", "rb"))
limitsX=[1840,1950]
limitsWord=[0,500]
color=['r','g','b']
sliding=10
hierarchy_plots(stats_global["divs"],limitsX,limitsWord, sliding, color, "hiérarchies pour le corpus restreint")

# %%
stats_global=pickle.load(open( "stats_global", "rb"))
limitsX=[1800,2000]
limitsWord=[0,40]
color=['r','g','b']
sliding=10
hierarchy_plots(stats_global["divs"],limitsX,limitsWord, sliding, color, "hiérarchies pour le corpus global")

# %%
stats_global=pickle.load(open( "stats_rest", "rb"))
limitsX=[1840,1950]
limitsWord=[2500,160000]
color='r'
sliding=10
simple_plot(stats_global["length"][0],limitsX,limitsWord, sliding, color, "masse de mots pour le corpus restreint")

# %%
stats_canon=pickle.load(open("stats_rest_canon", "rb"))
limitsX=[1840,1950]
limitsWord=[2500,200000]
color='r'
sliding=10
simple_plot(stats_canon["length"][0],limitsX,limitsWord, sliding, color, "masse de mots pour le corpus restreint pour les romans canoniques")

# %%
stats_non_canon=pickle.load(open("stats_rest_non-canon", "rb"))
limitsX=[1840,1950]
limitsWord=[2500,200000]
color='r'
sliding=10
simple_plot(stats_non_canon["length"][0],limitsX,limitsWord, sliding, color, "masse de mots pour le corpus restreint pour les romans non canoniques")

# %%
stats_global=pickle.load(open( "stats_rest", "rb"))
limitsX=[1840,1950]
limitsWord=[0,60000]
color=['r','g']
sliding=2
first_n_last_plots(stats_global["exts"],limitsX,limitsWord, sliding, color, "nombre de mots premiers et derniers chapitres --corpus restreint")

# %%
stats_global=pickle.load(open( "stats_rest_canon", "rb"))
limitsX=[1840,1950]
limitsWord=[0,60000]
color=['r','g']
sliding=2
first_n_last_plots(stats_global["exts"],limitsX,limitsWord, sliding, color, "nombre de mots premiers et derniers chapitres --corpus restreint canonique")

# %%
stats_global=pickle.load(open( "stats_rest_non-canon", "rb"))
limitsX=[1890,1950]
limitsWord=[0,60000]
color=['r','g']
sliding=1
first_n_last_plots(stats_global["exts"],limitsX,limitsWord, sliding, color, "nombre de mots premiers et derniers chapitres --corpus restreint non canonique")
